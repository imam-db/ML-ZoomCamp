# %%
import shutil
import os
import pprint

# %%
pprint.pprint(os.listdir('.'))
# Out:
# ['test.ipynb', 'train', 'validation']

# %%
img = os.listdir("c:\\Users\imamx\Documents\Sementara\Belajar\Machine Learning ZoomCamp\Week 7\\train\cats\\train")
# Out:
# ['cat.0.jpg',
#  'cat.1.jpg',
#  'cat.10.jpg',
#  'cat.100.jpg',
#  'cat.1000.jpg',
#  'cat.10000.jpg',
#  'cat.10001.jpg',
#  'cat.10002.jpg',
#  'cat.10003.jpg',
#  'cat.10004.jpg',
#  'cat.10005.jpg',
#  'cat.10006.jpg',
#  'cat.10007.jpg',
#  'cat.10008.jpg',
#  'cat.10009.jpg',
#  'cat.1001.jpg',
#  'cat.10010.jpg',
#  'cat.10011.jpg',
#  'cat.10012.jpg',
#  'cat.10013.jpg',
#  'cat.10014.jpg',
#  'cat.10015.jpg',
#  'cat.10016.jpg',
#  'cat.10017.jpg',
#  'cat.10018.jpg',
#  'cat.10019.jpg',
#  'cat.1002.jpg',
#  'cat.10020.jpg',
#  'cat.10021.jpg',
#  'cat.10022.jpg',
#  'cat.10023.jpg',
#  'cat.10024.jpg',
#  'cat.10025.jpg',
#  'cat.10026.jpg',
#  'cat.10027.jpg',
#  'cat.10028.jpg',
#  'cat.10029.jpg',
#  'cat.1003.jpg',
#  'cat.10030.jpg',
#  'cat.10031.jpg',
#  'cat.10032.jpg',
#  'cat.10033.jpg',
#  'cat.10034.jpg',
#  'cat.10035.jpg',
#  'cat.10036.jpg',
#  'cat.10037.jpg',
#  'cat.10038.jpg',
#  'cat.10039.jpg',
#  'cat.1004.jpg',
#  'cat.10040.jpg',
# ...

# %%
#x = 'cat'
#list_cats = []
#list_dogs = []

list_cats = [xx for xx in img if 'cat' in xx]
list_dogs = [xx for xx in img if 'dog' in xx]

#for xx in img:
#    if x in xx:
#        list_cats.append(x)
#    else:
#        list_dogs.append(x)

# %%
list_cats
# Out:
# ['cat.0.jpg',
#  'cat.1.jpg',
#  'cat.10.jpg',
#  'cat.100.jpg',
#  'cat.1000.jpg',
#  'cat.10000.jpg',
#  'cat.10001.jpg',
#  'cat.10002.jpg',
#  'cat.10003.jpg',
#  'cat.10004.jpg',
#  'cat.10005.jpg',
#  'cat.10006.jpg',
#  'cat.10007.jpg',
#  'cat.10008.jpg',
#  'cat.10009.jpg',
#  'cat.1001.jpg',
#  'cat.10010.jpg',
#  'cat.10011.jpg',
#  'cat.10012.jpg',
#  'cat.10013.jpg',
#  'cat.10014.jpg',
#  'cat.10015.jpg',
#  'cat.10016.jpg',
#  'cat.10017.jpg',
#  'cat.10018.jpg',
#  'cat.10019.jpg',
#  'cat.1002.jpg',
#  'cat.10020.jpg',
#  'cat.10021.jpg',
#  'cat.10022.jpg',
#  'cat.10023.jpg',
#  'cat.10024.jpg',
#  'cat.10025.jpg',
#  'cat.10026.jpg',
#  'cat.10027.jpg',
#  'cat.10028.jpg',
#  'cat.10029.jpg',
#  'cat.1003.jpg',
#  'cat.10030.jpg',
#  'cat.10031.jpg',
#  'cat.10032.jpg',
#  'cat.10033.jpg',
#  'cat.10034.jpg',
#  'cat.10035.jpg',
#  'cat.10036.jpg',
#  'cat.10037.jpg',
#  'cat.10038.jpg',
#  'cat.10039.jpg',
#  'cat.1004.jpg',
#  'cat.10040.jpg',
# ...

# %%
fnames = ['cat.{}.jpg'.format(i) for i in range(10000)]
for fname in fnames:
    src = os.path.join('C:\\Users\imamx\Documents\Sementara\Belajar\Machine Learning ZoomCamp\Week 7\\train\cats\\train', fname)
    dst = 'C:\\Users\imamx\Documents\Sementara\Belajar\Machine Learning ZoomCamp\Week 7\\train\cats'
    shutil.copy2(src, dst)

fnames = ['dog.{}.jpg'.format(i) for i in range(10000)]
for fname in fnames:
    src = os.path.join('C:\\Users\imamx\Documents\Sementara\Belajar\Machine Learning ZoomCamp\Week 7\\train\cats\\train', fname)
    dst = 'C:\\Users\imamx\Documents\Sementara\Belajar\Machine Learning ZoomCamp\Week 7\\train\dogs'
    shutil.copy2(src, dst)

fnames = ['cat.{}.jpg'.format(i) for i in range(10000,12500)]
for fname in fnames:
    src = os.path.join('C:\\Users\imamx\Documents\Sementara\Belajar\Machine Learning ZoomCamp\Week 7\\train\cats\\train', fname)
    dst = 'C:\\Users\imamx\Documents\Sementara\Belajar\Machine Learning ZoomCamp\Week 7\\validation\cats'
    shutil.copy2(src, dst)

fnames = ['dog.{}.jpg'.format(i) for i in range(10000, 12500)]
for fname in fnames:
    src = os.path.join('C:\\Users\imamx\Documents\Sementara\Belajar\Machine Learning ZoomCamp\Week 7\\train\cats\\train', fname)
    dst = 'C:\\Users\imamx\Documents\Sementara\Belajar\Machine Learning ZoomCamp\Week 7\\validation\dogs'
    shutil.copy2(src, dst)

# %%
[i for i in range(1, 5)]
# Out:
# [1, 2, 3, 4]
